# %% [markdown]
# # Estruturas de repetição
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um programa que peça uma nota, entre zero e dez. Mostre uma mensagem caso o valor seja inválido e continue pedindo até que o usuário informe um valor válido.

# %%
while True:
    valor = float(input('Qual o valor? (de 0 a 10)'))
    if not 0 <= valor <=10:
        print('Informe um valor valido!')
    else:
        print('Valor valido!')
        break
# Out:
# Informe um valor valido!
# Informe um valor valido!
# Informe um valor valido!
# Informe um valor valido!
# Valor valido!

# %% [markdown]
# #### 2. Faça um programa que leia um nome de usuário e a sua senha e não aceite a senha igual ao nome do usuário, mostrando uma mensagem de erro e voltando a pedir as informações.

# %%
while True:
    login = input('Informe seu login')
    senha = input('Informe sua senha')
    if login == senha:
        print('Erro, a senha nao pode ser igual ao login. Cdastre novamente!')
    else:
        print('Cadastrado com Sucesso!')
        break

# %% [markdown]
# #### 3. Faça um programa que leia e valide as seguintes informações (e para cada uma delas, continue pedindo a informação até o usuário inserir corretamente):
# ##### Nome: maior que 3 caracteres;
# ##### Idade: entre 0 e 150;
# ##### Salário: maior que zero;
# ##### Sexo: 'f' ou 'm';
# ##### Estado Civil: 's', 'c', 'v', 'd';

# %%
nome = input('Informe o nome: ')

while len(nome) < 4:
    print('Insira um nome com mais de 3 caracteres')
    nome = input('Informe o nome: ')
    
idade = int(input('Informe a idade: '))

while not (0 <= idade <= 150):
    print('Insira uma idade entre 0 e 150 anos')
    idade = int(input('Informe a idade: '))
    
salario = float(input('Informe o salário: '))

while salario <= 0:
    print('Insira um salário maior que zero')
    salario = float(input('Informe o salário: '))
    
genero = input('Informe o gênero "f" para feminino ou "m" para masculino: ')

while not genero in ['f', 'm']:
    print('Insira um gênero válido')
    genero = input('Informe o gênero "f" para feminino ou "m" para masculino: ')
    
estado_civil = input('Informe o estado civil "s", "c", "v" ou "d": ')

while not estado_civil in ['s', 'c', 'v', 'd']:
    print('Insira um estado civil válido')
    estado_civil = input('Informe o estado civil "s", "c", "v" ou "d": ')
# Out:
# Nome cadastrado com sucesso!
# Nome invalido, digite novamente
# Nome invalido, digite novamente
# Nome invalido, digite novamente
# Nome invalido, digite novamente
# Nome invalido, digite novamente
# Nome invalido, digite novamente
# Nome invalido, digite novamente
# Nome cadastrado com sucesso!
# Nome invalido, digite novamente
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 while True:
# ----> 2     nome = input('Qual o seu nome?')
#       3     if nome == '' or len(nome) < 3:
#       4         print('Nome invalido, digite novamente')
#
# File ~/Documents/Python/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~/Documents/Python/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #### 4. Supondo que a população de um país A seja da ordem de 80000 habitantes com uma taxa anual de crescimento de 3% e que a população de B seja 200000 habitantes com uma taxa de crescimento de 1.5%. Faça um programa que calcule e escreva o número de anos necessários para que a população do país A ultrapasse ou iguale a população do país B, mantidas as taxas de crescimento.

# %%
populacao_A = 80000
populacao_B = 200000

tempo = 0

while populacao_A < populacao_B:
    populacao_A *= 1.03
    populacao_B *= 1.015
    tempo += 1

print('São necessários', tempo, 'anos para a população A igualar ou superar a população B')
# Out:
# 63
# 2400.0

# %% [markdown]
# #### 5. Altere o programa anterior permitindo ao usuário informar as populações e as taxas de crescimento iniciais. Valide a entrada e permita repetir a operação.

# %%
tempo = 0

populacao_A = int(input('Qual a populacao da cidade A?'))

while populacao_A == 0:
    print('Erro no valor,digite novamente!')
    populacao_A = int(input('Qual a populacao da cidade A?'))

crecimento_a = float(input('Qual o crescimento populacional da cidade A?'))

while crecimento_a == 0:
    print('Erro no valor, digite novamente')
    crecimento_a = float(input('Qual o crescimento populacional da cidade A?'))

populacao_B = int(input('Qual a populacao da cidade B?'))

while populacao_B == 0:
    print('Erro no valor, digite novamente')
    populacao_B = int(input('Qual a populacao da cidade B?'))

crecimento_b = float(input('Qual o crescimento populacional da cidade B?'))

while crecimento_b == 0:
    print('Erro no valor, digite novamente')
    crecimento_b = float(input('Qual o crescimento populacional da cidade B?'))

crecimento_a = crecimento_a / 100 + 1
crecimento_b - crecimento_b / 100 + 1

while populacao_A < populacao_B:
    populacao_A *= crecimento_a
    populacao_B *= crecimento_b
    tempo += 1

print(tempo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 tempo = 0
# ----> 3 populacao_A = int(input('Qual a populacao da cidade A?'))
#       5 while populacao_A == 0:
#       6     print('Erro no valor,digite novamente!')
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# #### 6. Faça um programa que peça para o usuário inserir o faturamento dos últimos 5 meses (individualmente) e informe o maior faturamento

# %%
faturamentos = []

for i in range(5):
    faturamento_mes = float(input('Qual o faturamento do mes?'))
    faturamentos.append(faturamento_mes)
print('O maior faturamento eh de {}' .format(max(faturamentos)))
# Out:
# O maior faturamento eh de 50.0

# %% [markdown]
# #### 7. Faça um programa que peça para o usuário inserir o faturamento dos últimos 5 meses (individualmente) e informe o faturamento total (soma) e o faturamento médio por mês (média).

# %%
faturamentos = []
for i in range(5):
    faturamento_mes = float(input('Qual o faturamento do mes?'))
    faturamentos.append(faturamento_mes)

print('O faturamento total eh de {}' .format(sum(faturamentos)))
print('A media dos faturamento eh de {}' .format(sum(faturamentos)/len(faturamentos)))
# Out:
# O faturamento total eh de 150.0
# A media dos faturamento eh de 30.0

# %% [markdown]
# #### 8. Faça um programa que consiga categorizar a idade das equipes de uma empresa. Faça um programa que peça para n pessoas a sua idade, ao final o programa devera verificar se a média de idade da equipe varia entre 0 e 25 (jovem) ,26 e 60 (sênior) e maior que 60 (idosa); e então, dizer se a equipe é jovem, sênior ou idosa, conforme a média calculada.

# %%
idades = []

qtd = int(input('quantas pessoas serao verificadas?'))

for i in range(qtd):
    idade = int(input('Qual a idade?'))
    idades.append(idade)

media = sum(idades) / qtd

print(idades)

if 0 <= media <= 25:
    print('A media de idade da equipe eh JOVEM')
elif 26 <= media <= 60:
    print('A media de idade da equipe eh SENIOR')
else:
    print('A media de idade da equipe eh IDOSA')
# Out:
# 10
# 60
# [10, 60]
# A media de idade da equipe eh SENIOR

# %% [markdown]
# #### 9. Numa eleição existem três candidatos. Faça um programa que peça o número total de eleitores. Peça para cada eleitor votar e ao final mostrar o número de votos de cada candidato.

# %%
qtd = int(input('Quanto eleitores tera?'))

cont1 = 0
cont2 = 0
cont3 = 0

for i in range(qtd):
    voto = int(input('Qual seu voto? sendo 1, 2 ou 3'))
    if voto == 1:
        cont1 += 1
    elif voto == 2:
        cont2 += 1
    elif voto == 3:
        cont3 += 1

print('O candidato 1 teve {} votos\no candidato 2 teve {} votos \no candidato 3 teve {} votos' .format(cont1,cont2,cont3))
# Out:
# O candidato 1 teve 3 votos
# o candidato 2 teve 0 votos
# o candidato 3 teve 0 votos

# %% [markdown]
# #### 10. Faça um programa que calcule o valor total investido por um colecionador em sua coleção de CDs e o valor médio gasto em cada um deles. O usuário deverá informar a quantidade de CDs e o valor para em cada um.

# %%
qtd = int(input('Quantos CDs voce possui?'))

valor_total = 0

for i in range(qtd):
    valor = float(input('Qual o valor do cd?'))
    valor_total += valor

media = valor_total / qtd

print('O cliente gastou no total {} reais, com media por cd de {} reais' .format(valor_total,media))
# Out:
# O cliente gastou no total 15.0 reais, com media por cd de 7.5 reais

# %% [markdown]
# #### 11. O Sr. Manoel Joaquim possui uma grande loja de artigos de R\\$ 1,99, com cerca de 10 caixas. Para agilizar o cálculo de quanto cada cliente deve pagar ele desenvolveu um tabela que contém o número de itens que o cliente comprou e ao lado o valor da conta. Desta forma a atendente do caixa precisa apenas contar quantos itens o cliente está levando e olhar na tabela de preços. Você foi contratado para desenvolver o programa que monta esta tabela de preços, que conterá os preços de 1 até 50 produtos, conforme o exemplo abaixo:
# <pre>
# Lojas Quase Dois - Tabela de preços
# 1 - R$ 1.99
# 2 - R$ 3.98
# ...
# 50 - R$ 99.50
# </pre>

# %%
for i in range(50):
    print(' {} - R$ {:.2f}' .format(i+1,(i+1)*1.99))
# Out:
#  1 - R$ 1.99
#  2 - R$ 3.98
#  3 - R$ 5.97
#  4 - R$ 7.96
#  5 - R$ 9.95
#  6 - R$ 11.94
#  7 - R$ 13.93
#  8 - R$ 15.92
#  9 - R$ 17.91
#  10 - R$ 19.90
#  11 - R$ 21.89
#  12 - R$ 23.88
#  13 - R$ 25.87
#  14 - R$ 27.86
#  15 - R$ 29.85
#  16 - R$ 31.84
#  17 - R$ 33.83
#  18 - R$ 35.82
#  19 - R$ 37.81
#  20 - R$ 39.80
#  21 - R$ 41.79
#  22 - R$ 43.78
#  23 - R$ 45.77
#  24 - R$ 47.76
#  25 - R$ 49.75
#  26 - R$ 51.74
#  27 - R$ 53.73
#  28 - R$ 55.72
#  29 - R$ 57.71
#  30 - R$ 59.70
#  31 - R$ 61.69
#  32 - R$ 63.68
#  33 - R$ 65.67
#  34 - R$ 67.66
#  35 - R$ 69.65
#  36 - R$ 71.64
#  37 - R$ 73.63
#  38 - R$ 75.62
#  39 - R$ 77.61
#  40 - R$ 79.60
#  41 - R$ 81.59
#  42 - R$ 83.58
#  43 - R$ 85.57
#  44 - R$ 87.56
#  45 - R$ 89.55
#  46 - R$ 91.54
#  47 - R$ 93.53
#  48 - R$ 95.52
#  49 - R$ 97.51
#  50 - R$ 99.50

# %% [markdown]
# #### 12. Um funcionário de uma empresa recebe aumento salarial anualmente: Sabe-se que:
# <pre>
# Esse funcionário foi contratado em 1995, com salário inicial de R$ 1.000,00;
# Em 1996 recebeu aumento de 1,5% sobre seu salário inicial;
# A partir de 1997 (inclusive), os aumentos salariais sempre correspondem ao dobro do percentual do ano anterior. Faça um programa que determine o salário desse funcionário em 2003.
# </pre>

# %%
salario = 1000 * 1.015
aumento = 0.015

for i in range(1997, 2004):
    aumento = aumento * 2
    salario *= aumento + 1

print(salario)
# Out:
# 13036.153879241112

# %% [markdown]
# #### 13. O cardápio de uma lanchonete é o seguinte:
# <pre>
# Especificação   Código  Preço
# Cachorro Quente 100     R$ 1,20
# Bauru Simples   101     R$ 1,30
# Bauru com ovo   102     R$ 1,50
# Hambúrguer      103     R$ 1,20
# Cheeseburguer   104     R$ 1,30
# Refrigerante    105     R$ 1,00
# Faça um programa que leia o código dos itens pedidos e as quantidades desejadas. Calcule e mostre o valor a ser pago por item (preço * quantidade) e o total geral do pedido. Considere que o cliente deve informar quando o pedido deve ser encerrado.
# </pre>

# %%
valor_total = 0

codigo = input('Qual o codigo do item que deseja?')

while codigo != '':
    qtd = int(input('Qual a quantidade que deseja pedir do item ?'))

    if codigo == '100':
        valor = 1.20 * qtd
        valor_total += valor
        print('O valor a ser pago de Cachorro Quente eh de {} reais com {} unidades' .format(valor,qtd))
    elif codigo == '101':
        valor = 1.30 * qtd
        valor_total += valor
        print('O valor a ser pago de Bauru Simples eh de {} reais com {} unidades' .format(valor,qtd))
    elif codigo == '102':
        valor = 1.50 * qtd
        valor_total += valor
        print('O valor a ser pago de Bauru com ovo eh de {} reais com {} unidades' .format(valor,qtd))
    elif codigo == '103':
        valor = 1.20 * qtd
        valor_total += valor
        print('O valor a ser pago de Hamburgue eh de {} reais com {} unidades' .format(valor,qtd))
    elif codigo == '104':
        valor = 1.30 * qtd
        valor_total += valor
        print('O valor a ser pago de Cheeseburguer eh de {} reais com {} unidades' .format(valor,qtd))
    elif codigo == '105':
        valor = 1.00 * qtd
        valor_total += valor
        print('O valor a ser pago eh de Refrigerante eh de {} reais com {} unidades' .format(valor,qtd))
    else:
        print('Produto nao cadastrado')

    codigo = input('Qual o codigo do item que deseja?')

print('O valor total a ser pago eh de {} reais' .format(valor_total))
# Out:
# O valor a ser pago de Cachorro Quente eh de 8.4 reais com 7 unidades
# O valor total a ser pago eh de 8.4 reais

# %% [markdown]
# #### 14. Uma grande emissora de televisão quer fazer uma enquete entre os seus telespectadores para saber qual o melhor jogador após cada jogo. Para isto, faz-se necessário o desenvolvimento de um programa, que será utilizado pelas telefonistas, para a computação dos votos. Sua equipe foi contratada para desenvolver este programa, utilizando a linguagem de programação Python. Para computar cada voto, a telefonista digitará um número, entre 1 e 23, correspondente ao número da camisa do jogador. Um número de jogador igual zero, indica que a votação foi encerrada. Se um número inválido for digitado, o programa deve ignorá-lo, mostrando uma breve mensagem de aviso, e voltando a pedir outro número. Após o final da votação, o programa deverá exibir:
# <pre>a. O total de votos computados;
# b. Os números e respectivos votos de todos os jogadores que receberam votos;
# c. O percentual de votos de cada um destes jogadores;
# d. O número do jogador escolhido como o melhor jogador da partida, juntamente com o número de votos e o percentual de votos dados a ele.
#         Observe que os votos inválidos e o zero final não devem ser computados como votos. O resultado aparece ordenado pelo número do jogador. O programa deve fazer uso de arrays. O programa deverá executar o cálculo do percentual de cada jogador através de uma função. Esta função receberá dois parâmetros: o número de votos de um jogador e o total de votos. A função calculará o percentual e retornará o valor calculado. Abaixo segue uma tela de exemplo. O disposição das informações deve ser o mais próxima possível ao exemplo. Os dados são fictícios e podem mudar a cada execução do programa. Ao final, o programa deve ainda gravar os dados referentes ao resultado da votação em um arquivo texto no disco, obedecendo a mesma disposição apresentada na tela.</pre>
# ```
# Enquete: Quem foi o melhor jogador?
#
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 10
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 10
# Número do jogador (0=fim): 11
# Número do jogador (0=fim): 10
# Número do jogador (0=fim): 50
# Informe um valor entre 1 e 23 ou 0 para sair!
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 0
#
# Resultado da votação:
#
# Foram computados 8 votos.
#
# Jogador Votos           %
# 9               4               50,0%
# 10              3               37,5%
# 11              1               12,5%
# ```

# %%
votos = []
print('Enquete: Quem foi o melhor jogador?')
for i in range(23):
    votos.append(0)

while True:
    numero = int(input('Número do jogador (0=fim): '))
    if numero == 0:
        break
    elif not 1 <= numero <= 23:
        print('Informe um valor entre 1 e 23 ou 0 para sair!')
        continue
    votos[numero - 1] += 1

total = sum(votos)
print('Foram computados', total, 'votos.')
print('Jogador\tVotos\t%')
for i, voto in enumerate(votos):
    if voto > 0:
        print(f'{i+1}\t{voto}\t{voto/total:.1%}')
print(votos)
melhor = max(votos)
i = votos.index(melhor)
porcentagem = melhor/total
print(f'O melhor jogador foi o número {i+1}, com {melhor} votos, correspondendo a {porcentagem:.0%} do total de votos.')
