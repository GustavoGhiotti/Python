# %% [markdown]
# ### Exercício 1
# Crie um sistema de consulta de preços
# Seu sistema deve:
# - Pedir para o usuário o nome de um produto
# - Caso o produto exista na lista de produtos, o programa deve retornar o preço do produto como resposta
#        - Ex: O produto celular custa R$1500
# - Caso o produto não exista na lista de produtos, o programa deve printar uma mensagem para o usuário tentar novamente

# %%
precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 2000}

produto = input('Qual produto deseja consultar?')

if produto in precos:
    print('O preco do produto eh {} reais' .format(precos[produto]))
else:
    print('Produto {} nao cadastrado' .format(produto))
# Out:
# O preco do produto eh 1000 reais

# %% [markdown]
# ### Exercício 2
# Agora edite o programa anterior para fazer com que, caso não exista o produto, o programa pergunte se o usuário quer cadastrar o produto
# <br>Se ele responder sim, o programa deve pedir o nome do produto e o preco do produto e cadastrar no dicionário de preços
# <br>Em seguida do cadastro bem sucedido, o programa deve printar o dicionário de precos atualizado

# %%
precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 2000}

produto = input('Qual produto deseja consultar?')

if produto in precos:
    print('O preco do produto eh {} reais' .format(precos[produto]))
else:
    print('Produto {} nao cadastrado' .format(produto))
    cadastro = input('Deseja cadastrar um novo produtos (sim ou nao)')
    if cadastro == 'sim':
        novo_produto = input('Qual o produto que deseja cadastrar?')
        preco = float(input('Qual o valor do produto?'))
        precos[novo_produto] = preco
        print(precos)
# Out:
# Produto sei la nao cadastrado
# {'celular': 1500, 'camera': 1000, 'fone de ouvido': 800, 'monitor': 2000, 'sei la': 1000.0}

# %% [markdown]
# ### Exercício 3
# Dada a lista de preços de produtos, uma loja resolveu fazer um reajuste nos preços dos produtos.
# calcule o novo valor dos produtos com base nas seguintes regras:
# - Preços até 1.000 vão ter um reajuste de 10% (ou seja, o novo preço será 110% do preço atual)
# - Preços até maiores que 1.000 até 2.000 vão ter reajuste de 15%
# - Preços acima de 2.000 vão ter reajuste de 20%

# %%
precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 3000}

for item in precos:
    if precos[item] < 1000:
        precos[item] *= 1.1
    elif 1000 <= precos[item] < 2000:
        precos[item] *= 1.15
    else:
        precos[item] *= 1.20

    print('O produto {} tem o novo valor de {} reais' .format(item,precos[item]))
# Out:
# O produto celular tem o novo valor de 1724.9999999999998 reais
# O produto camera tem o novo valor de 1150.0 reais
# O produto fone de ouvido tem o novo valor de 880.0000000000001 reais
# O produto monitor tem o novo valor de 3600.0 reais

# %% [markdown]
# ### Exercício 4
#  - Edite o programa antigo para ter os 2 dicionários, o de preços originais e o de novos preços
#  - Em seguida calcule o valor total de reajuste em R$ que teve entre a lista de produtos original e a lista final

# %%
precos = {"celular": 1500, "camera": 1000, "fone de ouvido": 800, "monitor": 3000}

precos_novos = {}

for item in precos:
    novos_precos = precos[item]
    if precos[item] <= 1000:
        novos_precos = precos[item] * 1.1
    elif precos[item] <= 2000:
        novos_precos = precos[item] * 1.15
    else:
        novos_precos = precos[item] * 1.20
    print('O produto {} tem o novo valor de {} reais' .format(item,novos_precos))
    precos_novos[item] = novos_precos

precos_total = sum(precos.values())
novos_total = sum(precos_novos.values())
reajuste = novos_total - precos_total

print('Teve uma diferenca de {} reais para os precos antigos e os novos com o reajuste' .format(reajuste))
# Out:
# O produto celular tem o novo valor de 1724.9999999999998 reais
# O produto camera tem o novo valor de 1100.0 reais
# O produto fone de ouvido tem o novo valor de 880.0000000000001 reais
# O produto monitor tem o novo valor de 3600.0 reais
# Teve uma diferenca de 1005.0 reais para os precos antigos e os novos com o reajuste

# %% [markdown]
# ### Exercício 5
# - Uma empresa está analisando os resultados de vendas do 1º semestre de 2022 e 2023
# - Qual foi o % de crescimento de cada mês de 2023 em relação a 2022?
# - Depois de calcular isso, calcule o valor total de crescimento de 2023 em relação a 2022

# %%
vendas_22 = {"jan": 15000, "fev": 15500, "mar": 14000, "abr": 16600, "mai": 16300, "jun": 17000}
vendas_23 = {"jan": 17000, "fev": 15000, "mar": 17500, "abr": 16900, "mai": 16000, "jun": 18500}

for mes in vendas_22:
    valor22 = vendas_22[mes] 
    valor23 = vendas_23[mes]
    crescimento = valor23 / valor22 - 1
    print('O crescimento do mes {} foi de {:.2%}' .format(mes,crescimento))

total22 = sum(vendas_22.values())
total23 = sum(vendas_23.values())
crescimento_total = total23 / total22 - 1

print('O crescimento total eh de {:.2%}' .format(crescimento_total))
# Out:
# O crescimento do mes jan foi de 13.33%
# O crescimento do mes fev foi de -3.23%
# O crescimento do mes mar foi de 25.00%
# O crescimento do mes abr foi de 1.81%
# O crescimento do mes mai foi de -1.84%
# O crescimento do mes jun foi de 8.82%
# O crescimento total eh de 6.89%

# %% [markdown]
# ### Exercício 6 - Desafio
# - No final da reunião de apresentação dos números, seu chefe perguntou:
# - E se nos meses de 2023 que a gente vendeu menos do que 2022 a gente tivesse pelo menos empatado com 2022 (ou seja, se nos meses de 2023 em que as vendas foram menores do que o mesmo mês em 2022, o valor de vendas tivesse sido igual a 2022)
# - Qual teria sido o nosso crescimento de 2023 frente a 2022?

# %%
vendas_22 = {"jan": 15000, "fev": 15500, "mar": 14000, "abr": 16600, "mai": 16300, "jun": 17000}
vendas_23 = {"jan": 17000, "fev": 15000, "mar": 17500, "abr": 16900, "mai": 16000, "jun": 18500}

for mes in vendas_22:
    valor22 = vendas_22[mes] 
    valor23 = vendas_23[mes]
    if valor23 < valor22:
        vendas_23[mes] = valor22
    crescimento = valor23 / valor22 - 1
    print('O crescimento do mes {} foi de {:.2%}' .format(mes,crescimento))

total22 = sum(vendas_22.values())
total23 = sum(vendas_23.values())
crescimento_total = total23 / total22 - 1

print('O crescimento total eh de {:.2%}' .format(crescimento_total))
# Out:
# O crescimento do mes jan foi de 13.33%
# O crescimento do mes fev foi de -3.23%
# O crescimento do mes mar foi de 25.00%
# O crescimento do mes abr foi de 1.81%
# O crescimento do mes mai foi de -1.84%
# O crescimento do mes jun foi de 8.82%
# O crescimento total eh de 7.73%
